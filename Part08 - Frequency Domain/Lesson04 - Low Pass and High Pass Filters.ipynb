# %% [markdown]
# # Lesson04   Low Pass and High Pass Filters
#
# ## Why This Lesson
# Every image is made of waves. Seeing in frequency is a superpower.
#
# ## Concepts
# This lesson covers the core theory and practical implementation of lesson04  low pass and high pass filters.
#
# ## Code

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load sample image
img = cv2.imread('sample.jpg')
if img is None:
    print("Place a sample.jpg in this folder to run these examples")
    import numpy as np
    img = np.random.randint(0, 255, (480, 640, 3), dtype=np.uint8)

print("Image loaded:", img.shape)
# ── Your code for this lesson goes here ──

# %% [markdown]
# ## Activities
# Complete the activities in Activities.md for this part.
#
# ## Key Takeaway
# Study this concept deeply — it connects directly to the next lesson.
