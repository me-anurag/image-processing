# %% [markdown]
# # Lesson05 - Exposure Compensation
#
# ## Why This Lesson
# Features + matching + homography + blending = panorama. The complete pipeline.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = cv2.imread('sample.jpg')
if img is None:
    img = np.random.randint(0, 255, (480, 640, 3), dtype=np.uint8)

print("Image loaded:", img.shape)
print("Complete the code for this lesson using the concepts described in the curriculum.")
print("Refer to Activities.md and MiniProject.md for guided exercises.")

# %% [markdown]
# ## Key Takeaway
# Study this concept, implement it, then move to the activities.
# The mini project for this part integrates all lessons together.
